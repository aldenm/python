# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_json("https://performance.smcgov.org/resource/vp7a-42ze.json") #read json data source
dfclean = df.drop( ['total_number_of_homeless_individuals', 'date'], axis=1 ) #remove columns
dfindexed = dfclean.set_index("year") #set index to year

# %%
dfindexed.T.plot.bar()
# Out:
# <AxesSubplot:>

# %%
dfindexed.T.plot.bar(subplots=True, figsize=(6,6))
# Out:
# array([<AxesSubplot:title={'center':'2013'}>,
#        <AxesSubplot:title={'center':'2011'}>,
#        <AxesSubplot:title={'center':'2009'}>,
#        <AxesSubplot:title={'center':'2007'}>], dtype=object)
